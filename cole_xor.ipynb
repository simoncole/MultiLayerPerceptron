# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# import modules

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

# %% [markdown]
# Load and split the data

# %%
data = np.loadtxt('/content/drive/MyDrive/xor.csv', delimiter=',', skiprows=1)
data_train = data[:,:-1]
class_train = data[:, -1]
print('data:', data_train.shape)
print('class:', class_train.shape)
# Out:
# data: (4, 2)
# class: (4,)

# %% [markdown]
# Create and train model

# %%
model=Sequential()
model.add(Dense(5, input_shape=(2,), activation='relu')) 
model.add(Dense(1, activation='sigmoid')) 
model.compile(optimizer='rmsprop', loss='binary_crossentropy',
metrics=['accuracy']) 
print(model.summary())
model.fit(data_train, class_train, epochs=3000, batch_size=1)
# Out:
# Streaming output truncated to the last 5000 lines.
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3007 - accuracy: 0.7500
# Epoch 502/3000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3001 - accuracy: 0.7500
# Epoch 503/3000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2999 - accuracy: 0.7500
# Epoch 504/3000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2991 - accuracy: 0.7500
# Epoch 505/3000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2989 - accuracy: 0.7500
# Epoch 506/3000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2980 - accuracy: 0.7500
# Epoch 507/3000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2995 - accuracy: 0.7500
# Epoch 508/3000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2973 - accuracy: 0.7500
# Epoch 509/3000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2972 - accuracy: 0.7500
# Epoch 510/3000
# ...

# %% [markdown]
# make predictions

# %%
pred = model.predict(data_train)
print(pred)
# Out:
# 1/1 [==============================] - 0s 97ms/step
# [[1.1011859e-05]
#  [8.0219012e-05]
#  [3.5122040e-04]
#  [9.7762752e-01]]

# %% [markdown]
# [[1.1011859e-05]
#  [8.0219012e-05]
#  [3.5122040e-04]
#  [9.7762752e-01]]
